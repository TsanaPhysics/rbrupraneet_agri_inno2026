# %% [markdown]
# # Workshop 2: Session 4 - Evaluation & Inference
# Developed by RBRU-Praneet Agri-Innovation Center (2026)
#
# Measuring our AI's performance and testing it on new, unseen plant images.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Mock Training Analysis
epochs = range(1, 11)
accuracy = [0.5, 0.6, 0.72, 0.78, 0.85, 0.88, 0.91, 0.93, 0.94, 0.96]

plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.title('Training Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

print("AI Model Ready for Deployment! Graduation Complete! 🎉")
