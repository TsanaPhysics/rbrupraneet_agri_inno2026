# %% [markdown]
# # Workshop 2: Session 2 - Data Augmentation
# Developed by RBRU-Praneet Agri-Innovation Center (2026)
#
# Learn how to multiply your leaf dataset using random rotations and flips to make your AI more robust.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt

# 1. Setup Augmentation
datagen = ImageDataGenerator(
    rotation_range=40, width_shift_range=0.2, 
    height_shift_range=0.2, horizontal_flip=True, fill_mode='nearest'
)

print("ImageDataGenerator ready for training data expansion!")
