# %% [markdown]
# # ศูนย์บัญชาการสด (Telemetry Streams)
# ## แพ็คเกจแบบโครงข่ายใหญ่ (Bulk Matrix)

# %%
# แทนที่จะส่งทีละเส้น ให้รวม 10 ค่าล่าสุดในอาร์เรย์แล้วส่งทีเดียว
bulk_data = {'temperature_history': [32.1, 32.2, 32.5, 33.0, 33.1]}
pack = json.dumps(bulk_data)
print('📦 เตรียมส่งชุดข้อมูลระดับ Big Data ย่อย 1 ก้อน:', pack)
