# %% [markdown]
# # เซ็นเซอร์สภาพแวดล้อม (I2C Sensors)
# ## คำนวณ Heat Index

# %%
# ดัชนีความร้อน คืออุณหภูมิที่ต้นไม้ 'รู้สึก' จริงๆ
heat_index = temp + (0.5555 * (humid - 10.0))
print(f'⚠️ พืชกำลังแบกรับความร้อนที่สัมผัสได้: {heat_index:.1f}°C')
