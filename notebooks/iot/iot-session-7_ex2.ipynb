# %% [markdown]
# # รักษาความลับการค้า (IoT Edge Security)
# ## การตรวจสอบลายเซ็น (Digital Signature)

# %%
# เมื่อเซิร์ฟเวอร์ได้รับระบบ จะแนบลายเซ็นมาเทียบเคียงแบบสมมาตร
expected_signature = b'a5f8...'
if encrypted == expected_signature:
    print('✅ คำสั่งนี้ของแท้ สั่งให้ปั๊มน้ำทำงาน!')
else:
    print('❌ แจ้งเตือน: มีการปลอมแปลงคำสั่ง!')
