# %% [markdown]
# # จอแสดงผลกลางสวน (OLED I2C)
# ## วาดกราฟิกสถานะแทงก์น้ำ

# %%
# วาดกรอบสี่เหลี่ยมแทนถังน้ำ (x, y, w, h, สลับสี)
display.rect(100, 10, 20, 50, 1)
# เติมพิกเซลความสูงตามระดับน้ำจริง
display.fill_rect(100, 30, 20, 30, 1) 
display.show()
