# %% [markdown]
# # ศูนย์บัญชาการสด (Telemetry Streams)
# ## ตัดการเชื่อมต่อเพื่อป้องระบบรวน (Graceful Exit)

# %%
try:
    # ..loop logic..
    pass
except KeyboardInterrupt:
    print('⚠️ หยุดการทำงานจาก Admin... ถอนตัวออกจาก Cloud อย่างปลอดภัย')
    client.disconnect()
    wlan.disconnect()
