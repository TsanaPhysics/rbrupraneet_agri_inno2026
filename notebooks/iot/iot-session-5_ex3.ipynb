# %% [markdown]
# # เชื่อมต่อโลกผ่าน Wi-Fi (Networking)
# ## ตรวจสอบ IP Address

# %%
# ขอตรวจสอบตั๋ว IP จาก Router
status = wlan.ifconfig()
print('🌐 IP ประจำตัวของเครื่องนี้คือ:', status[0])
print('เส้นทาง Gateway ขาออกคือ:', status[2])
