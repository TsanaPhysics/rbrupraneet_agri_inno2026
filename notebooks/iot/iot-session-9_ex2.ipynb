# %% [markdown]
# # สมาร์ทวาล์วและรีเลย์ (Robotic Actions)
# ## สร้างฟังก์ชันทดน้ำ (Irrigation Routine)

# %%
def water_plant(duration_seconds):
    print(f'💧 เริ่มรดน้ำเป็นเวลา {duration_seconds} วินาที')
    pump_relay.value(0)
    time.sleep(duration_seconds)
    pump_relay.value(1)
    print('🚫 ปิดปั๊มเรียบร้อย!')
