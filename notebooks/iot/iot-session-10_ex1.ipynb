# %% [markdown]
# # สลีปโหมดเซฟโลก (Deep Sleep Mastery)
# ## ปิดระบบสัญญาณทุกอย่าง (Light Sleep)

# %%
import machine

print('ปิดระบบสมองซีกนอกและไวไฟชั่วคราว เพื่อประหยัดแบตเตอรี่')
machine.lightsleep(5000) 
print('ตื่นแล้ว! สถานะ CPU ปกติ')
