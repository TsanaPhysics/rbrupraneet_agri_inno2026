# %% [markdown]
# # จำลองโลกคู่ขนานดิจิทัล (Digital Twin Capstone)
# ## Launch The System โชว์ผลลัพธ์

# %%
if __name__ == '__main__':
    run_capstone()
    the_smart_loop()
    
    print('👉 (ในห้องทดลองจริง คุณจะได้เห็นภาพโฮโลแกรมต้นไม้ของคุณโตขึ้นในสัดส่วนที่ตรงกันกับเซ็นเซอร์!)')
