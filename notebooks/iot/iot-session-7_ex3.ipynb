# %% [markdown]
# # รักษาความลับการค้า (IoT Edge Security)
# ## การจัดการตัวแปรลับ (Secrets.py)

# %%
# แยกไฟล์รหัสผ่านออกไปจากไฟล์ main.py เพื่อป้องกันความคุ้นชิน
# ให้สร้างไฟล์ใหม่ชื่อ secrets.py และนำไปเก็บซ่อนในบอร์ด 
import secrets 
print('ตู้เซฟถูกเปิดโดยไฟล์ที่ซ่อนอยู่ Password_DB:', secrets.WIFI_PASS)
