# %% [markdown]
# # สลีปโหมดเซฟโลก (Deep Sleep Mastery)
# ## วิชาจำศีลลึก (Deep Sleep Configuration)

# %%
# เซ็นเซอร์จะตัดไฟตัวเอง 100% (แรมถูกลบ) เพื่อเก็บกระแสไฟนานแรมเดือน
# และจะบูทตัวเองใหม่เมื่อถึงเวลา

print('💤 กำลังเข้าสู่โหมดจำศีล (Deep Sleep) 1 ชั่วโมง...')
machine.deepsleep(3600 * 1000)
