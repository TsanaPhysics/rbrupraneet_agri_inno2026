# %% [markdown]
# # หาร่องรอย (Feature Extraction)
# ## เบลอภาพเพื่อลดจุดรบกวน

# %%
# เบลอภาพแบบ Gaussian ก่อนหาขอบ เพื่อลดสิ่งสกปรกบนใบพืช
blurred = cv2.GaussianBlur(gray_img, (5, 5), 0)
plt.imshow(blurred, cmap='gray')
plt.show()
