# %% [markdown]
# # จำลองพันธุกรรมข้อมูล (Data Augmentation)
# ## Normalization สู่ 0-1

# %%
# แปลงค่าพิกเซล 0-255 ให้กลายเป็นทศนิยม
normalized_dataset = ImageDataGenerator(rescale=1./255)
print('ลดทอนสัญญาณทุกภาพเพื่อการคำนวณที่รวดเร็วขึ้น!')
