# %% [markdown]
# # เชื่อมท่อส่งข้อมูล (Data Flow Generator)
# ## ตรวจสอบ Class Index

# %%
# ตรวจสอบว่า AI กำหนดรหัส 0, 1, 2 ให้กับโรคใดบ้าง
labels = (train_generator.class_indices)
print('รหัสโรคพืชที่จะเรียนรู้:', labels)
