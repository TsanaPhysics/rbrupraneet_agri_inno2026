# %% [markdown]
# # ส่งมอบพลังสู่โลกกว้าง (Deploy to Drone)
# ## คำสั่งแปลงสู่ TFLite

# %%
# กระบวนการ Quantization แปลงสมองเป็นไฟล์รหัสเบาสำหรับมือถือและโดรน
tflite_model = converter.convert()
with open('drone_ai_vision.tflite', 'wb') as f:
    f.write(tflite_model)
print('✅ แปลงไฟล์สำเร็จ: drone_ai_vision.tflite')
