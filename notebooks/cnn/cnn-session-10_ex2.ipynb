# %% [markdown]
# # ระเบียบการเรียน (Compile Models)
# ## ผูกสมการเรียนรู้

# %%
# ใช้ categorical_crossentropy เพราะเรามีเป้าหมายมากกว่า 2 โรค
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
