# %% [markdown]
# # ชั้นสกลัดลอจิก (The Secret of Tensors)
# ## แปลงคืนเป็นภาพมนุษย์

# %%
# ลองเอาค่า Tensor แปลงกลับมาให้คนดู
sample = x_batch[0]
plt.imshow(sample)
plt.title('Tensor Recovered')
plt.show()
