# %% [markdown]
# # ฝึกฝนสุนัขดมกลิ่น (Training AI)
# ## บันทึกสมองกลสู่ไฟล์ .H5

# %%
# บันทึกน้ำหนักสมองเก็บไว้ เผื่อส่งต่อให้เพื่อนร่วมทีม
model.save('rbru_plant_model.h5')
print('Saved Model Checkpoint Successfully!')
