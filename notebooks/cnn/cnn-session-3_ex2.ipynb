# %% [markdown]
# # ครอบตัดจุดตาย (Precision Cropping)
# ## ย่อขยายขนาด (Resizing)

# %%
# บีบขนาดถาพให้เป็น 224x224 พิกเซล เตรียมป้อนเข้าสู่โมเดล
resized_leaf = cv2.resize(cropped_leaf, (224, 224))
print('ขนาดภาพใหม่:', resized_leaf.shape)
plt.imshow(resized_leaf)
plt.show()
