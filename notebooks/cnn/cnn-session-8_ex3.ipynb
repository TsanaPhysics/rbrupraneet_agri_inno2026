# %% [markdown]
# # หัวใจเครื่องจักร (The Neural Architecture)
# ## การย่อขนาด (MaxPooling)

# %%
# ย่อขนาดฟิลเจอร์ลงครึ่งหนึ่งเพื่อให้ประมวลผลเร็วขึ้น
model.add(MaxPooling2D(pool_size=(2, 2)))
print('เพิ่มชั้นลดความซับซ้อน Pooling Layer พร้อมแล้ว')
