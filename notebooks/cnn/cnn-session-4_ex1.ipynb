# %% [markdown]
# # จัดการคลังภาพ (Dataset Prep)
# ## ตรวจเช็กโฟลเดอร์ด้วย Python OS

# %%
import os

dataset_path = 'dataset/train/'
classes = os.listdir(dataset_path)
print('พบประเภทของโรคในระบบ:', classes)
