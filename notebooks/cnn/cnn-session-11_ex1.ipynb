# %% [markdown]
# # ฝึกฝนสุนัขดมกลิ่น (Training AI)
# ## ปล่อยพลังประมวลผล (Model Fit)

# %%
# ให้นักเรียนลองปรับใช้ epochs=10
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator,
    callbacks=[stop_early]
)
print('การหล่อหลอมปัญญาประดิษฐ์เสร็จสิ้น!')
