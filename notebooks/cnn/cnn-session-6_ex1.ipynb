# %% [markdown]
# # เชื่อมท่อส่งข้อมูล (Data Flow Generator)
# ## ผูกท่อเข้ากับโฟลเดอร์ (Flow from Directory)

# %%
train_generator = normalized_dataset.flow_from_directory(
    'dataset/train/',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
print('ท่อส่งข้อมูล Train พร้อมทำงาน')
