# %% [markdown]
# # ชั้นสกลัดลอจิก (The Secret of Tensors)
# ## การเช็ก Labels Tensors

# %%
print('รูปแบบของคำตอบขาเข้า (หมวดหมู่โรค):', y_batch.shape)
print('ตัวอย่างคำตอบแบบ One-hot encoding:', y_batch[0])
