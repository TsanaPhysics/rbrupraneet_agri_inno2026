# %% [markdown]
# # เชื่อมท่อส่งข้อมูล (Data Flow Generator)
# ## ผูกท่อตรวจสอบ (Validation Flow)

# %%
val_generator = normalized_dataset.flow_from_directory(
    'dataset/val/',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
print('ท่อส่งข้อมูล Validation พร้อมทำงาน')
