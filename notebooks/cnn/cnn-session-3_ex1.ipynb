# %% [markdown]
# # ครอบตัดจุดตาย (Precision Cropping)
# ## Matrix Slicing 101

# %%
# ตัดภาพให้เหลือเฉพาะตรงกลางแกน Y และ X
cropped_leaf = img_rgb[100:400, 200:500]
plt.imshow(cropped_leaf)
plt.title('Cropped Disease Area')
plt.show()
