# %% [markdown]
# # หาร่องรอย (Feature Extraction)
# ## ใช้งาน Canny Edge Detector

# %%
# ตรวจจับเส้นขอบ โดยปรับลดตัวเลข 50 และ 150 เพื่อรับความไวแสง
edges = cv2.Canny(blurred, 50, 150)
plt.imshow(edges, cmap='gray')
plt.title('Leaf Edge Detection')
plt.show()
