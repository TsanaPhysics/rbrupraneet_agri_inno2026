# %% [markdown]
# # ชั้นสกลัดลอจิก (The Secret of Tensors)
# ## การสำรวจ Tensor Shape

# %%
# สุ่มดึงภาพมา 1 Batch (32 รูป)
x_batch, y_batch = next(train_generator)

# รูปทรงจะออกมาเป็น (32, 224, 224, 3)
print('รูปแบบของ Tensor ขาเข้า:', x_batch.shape)
