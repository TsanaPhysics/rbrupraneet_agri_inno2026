# %% [markdown]
# # ด่านแรก: พิกเซลและสีสัน (Pixels & Colors)
# ## ชำแหละพิกเซล (Matrix Slice)

# %%
# ดึงค่าสีจากมุมซ้ายบนของภาพ (ตำแหน่งพิกเซล (10,10))
pixel_color = img_rgb[10, 10]
print(f'สี RGB: Red={pixel_color[0]}, Green={pixel_color[1]}, Blue={pixel_color[2]}')
