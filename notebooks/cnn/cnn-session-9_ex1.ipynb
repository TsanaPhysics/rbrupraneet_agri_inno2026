# %% [markdown]
# # ต่อยอดสมองสู่ปัญญาชน (Deep Architecture)
# ## แบนข้อมูลด้วย Flatten

# %%
# ปรับภาพ 2D ให้แบนลงเป็น 1 เส้นตรงมิติ
model.add(Flatten())
print('แบนข้อมูลเป็น 1 มิติเรียบร้อย เพื่อเตรียมเข้า Dense')
