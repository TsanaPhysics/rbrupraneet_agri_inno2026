# %% [markdown]
# # หัวใจเครื่องจักร (The Neural Architecture)
# ## สร้างโครงข่ายเปล่า

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# สร้างภาชนะรับสมองกล
model = Sequential()
print('เปิดระบบ Sequential สำเร็จ')
