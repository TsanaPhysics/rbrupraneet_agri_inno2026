# %% [markdown]
# # ด่านแรก: พิกเซลและสีสัน (Pixels & Colors)
# ## ย้อมสีวิเคราะห์โรค (Grayscale)

# %%
# แปลงภาพเป็นโหมดขาวดำ เพื่อลดความซับซ้อนให้ AI
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray_img, cmap='gray')
plt.title('Grayscale Analysis')
plt.show()
