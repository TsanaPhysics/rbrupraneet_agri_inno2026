# %% [markdown]
# # หัวใจเครื่องจักร (The Neural Architecture)
# ## สร้างตามดวงตา CNN

# %%
# เพิ่มชั้น Conv2D ทำหน้าที่กวาดสายตาหาเส้นขอบ
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)))
print('ชั้นตรวจจับและ Activation ReLU ถูกติดตั้ง')
