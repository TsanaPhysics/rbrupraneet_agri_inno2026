# %% [markdown]
# # จัดการคลังภาพ (Dataset Prep)
# ## นับจำนวนทหาร (Count Files)

# %%
# นับจำนวนรูปทั้งหมดในแต่ละหมวด
for cls in classes:
    count = len(os.listdir(f'{dataset_path}/{cls}'))
    print(f'หมวดหมู่ {cls} มีรูปภาพให้เรียนรู้ {count} รูป')
