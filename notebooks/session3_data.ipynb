# %% [markdown]
# # Climate Data Hacking: Session 3 - Data Detective
# Developed by RBRU-Praneet Agri-Innovation Center (2026)
#
# ---
#
# > [!NOTE]
# > Students need to upload `chanthaburi_climate_sample.csv` to Colab before running this.

# %%
import pandas as pd

# อ่านข้อมูลจากไฟล์ที่ดาวน์โหลดมา
try:
    df = pd.read_csv('chanthaburi_climate_sample.csv')
    # ค้นหาเดือนที่ฝนตกหนักที่สุด (Heavy Rain)
    heavy_rain_months = df[df['Status'] == 'Heavy Rain']

    print("--- รายงานความผิดปกติของฝน ---")
    print(heavy_rain_months[['Year', 'Month', 'Rainfall_mm']])
except FileNotFoundError:
    print("กรุณาอัปโหลดไฟล์ chanthaburi_climate_sample.csv ก่อนรันโค้ดนะครับ!")
