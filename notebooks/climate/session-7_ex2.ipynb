# %% [markdown]
# # ถอดรหัส Dictionary
# ## Ex 7.2: Dictionary ซ้อนทับ (Nested)

# %%
api_mock = {"station": "Chanthaburi", "sensors": {"t1": 32, "t2": 31}}
print("Temp Zone 1:", api_mock["sensors"]["t1"])
