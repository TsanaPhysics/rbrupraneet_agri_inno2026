# %% [markdown]
# # Data Forensics (หาสิ่งผิดปกติ)
# ## Ex 10.2: Moving Average

# %%
import pandas as pd
daily_rain = pd.Series([0, 10, 50, 0, 0, 0, 30])
# ค้นหาค่าเฉลี่ย 3 วัน
print(daily_rain.rolling(window=3).mean())
