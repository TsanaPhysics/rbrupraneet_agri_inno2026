# %% [markdown]
# # Capstone: RBRU AI DSS
# ## Ex 12.2: Loop Tracking

# %%
farm_data = [{'t': 36, 'h': 35}, {'t': 28, 'h': 60}]
for reading in farm_data:
    action = dss_engine(reading['t'], reading['h'])
    print(f"Action Executed: {action}")
