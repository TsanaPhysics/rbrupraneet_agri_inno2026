# %% [markdown]
# # ตัวแปรและข้อมูลฟาร์ม (Variables)
# ## Ex 1.3: String - เปลี่ยนชื่อสายพันธุ์

# %%
# ให้นักเรียนลองเปลี่ยนชื่อจาก Monthong เป็นสายพันธุ์อื่น
breed = "Monthong (หมอนทอง)"
print(f"โซน A ปลูกสายพันธุ์: {breed}")
