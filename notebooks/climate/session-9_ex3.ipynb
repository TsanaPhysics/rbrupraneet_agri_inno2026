# %% [markdown]
# # ข้อมูลระดับบิ๊กดาต้า (Pandas)
# ## Ex 9.3: Filtering กรองวันวิกฤต

# %%
import pandas as pd
df = pd.DataFrame({'Temp': [31, 36, 30, 37]})
hot_days = df[df['Temp'] > 35]
print("วันที่ร้อนจัด:\n", hot_days)
