# %% [markdown]
# # ข้อมูลแถวคอย (Lists & Arrays)
# ## Ex 4.3: การเพิ่มอุปกรณ์ใหม่ (Append)

# %%
devices = ["Valve_1", "Valve_2"]
devices.append("Valve_3_New")
print("อุปกรณ์หลังติดตั้งใหม่:", devices)
