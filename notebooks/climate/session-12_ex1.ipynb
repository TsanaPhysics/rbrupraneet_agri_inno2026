# %% [markdown]
# # Capstone: RBRU AI DSS
# ## Ex 12.1: Master Logic Function

# %%
def dss_engine(t, h):
    if t > 35 and h < 40:
        return "START_MISTING"
    return "IDLE"

print(dss_engine(36, 30))
