# %% [markdown]
# # สร้างกราฟแสดงทัศนวิสัย (Visualization)
# ## Ex 11.1: Line Plot (สายเวลา)

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3], [32, 33, 35], color='orange')
plt.title("Temperature Trend")
# plt.show()
