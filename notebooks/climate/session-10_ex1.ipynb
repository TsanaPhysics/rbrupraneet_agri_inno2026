# %% [markdown]
# # Data Forensics (หาสิ่งผิดปกติ)
# ## Ex 10.1: การไล่เรียงข้อมูล (Sorting)

# %%
import pandas as pd
df = pd.DataFrame({'Yr': [2020, 2021], 'Rain': [1500, 800]})
print(df.sort_values(by='Rain'))
