# %% [markdown]
# # ข้อมูลระดับบิ๊กดาต้า (Pandas)
# ## Ex 9.2: ถอดค่าสถิติเบื้องต้น

# %%
import pandas as pd
temps = pd.Series([31, 33, 35, 36, 32])
print(f"อุณหภูมิเฉลี่ย: {temps.mean()} C")
print(f"ร้อนสุดในรอบสัปดาห์: {temps.max()} C")
