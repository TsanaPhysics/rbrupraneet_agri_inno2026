# %% [markdown]
# # การคำนวณทางเกษตรศาสตร์ (Agri-Math)
# ## Ex 2.1: คำนวณความต้องการน้ำ

# %%
water_per_tree = 20.5  # ลิตร
tree_count = 50
total_water = water_per_tree * tree_count
print(f"น้ำทั้งหมดที่ต้องการ: {total_water} ลิตร")
