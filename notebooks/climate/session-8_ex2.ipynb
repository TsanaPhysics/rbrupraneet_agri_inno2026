# %% [markdown]
# # API Cloud Connections
# ## Ex 8.2: การสกัดจุดข้อมูล (Extraction)

# %%
weather_api = {"data": {"stations": [{"name": "Chanthaburi", "rain": 45}]}}
ch_rain = weather_api["data"]["stations"][0]["rain"]
print(f"ฝนที่ตก: {ch_rain} mm")
