# %% [markdown]
# # Data Forensics (หาสิ่งผิดปกติ)
# ## Ex 10.3: ค้นหาจุดต่ำสุด

# %%
import pandas as pd
df = pd.DataFrame({'Yr': [2021,2022], 'Yield': [12000, 4500]})
crisis_yr = df[df['Yield'] == df['Yield'].min()]
print("ปีที่วิกฤตผลผลิต:\n", crisis_yr)
