# %% [markdown]
# # การคำนวณทางเกษตรศาสตร์ (Agri-Math)
# ## Ex 2.3: Modulo - การแบ่งโซนรดน้ำ

# %%
row_count = 14
zone_split = row_count % 3
print(f"ต้นไม้ที่เหลือจากจัดกลุ่มโซนละ 3 แถว: {zone_split}")
