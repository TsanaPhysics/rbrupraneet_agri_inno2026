# %% [markdown]
# # สร้างกราฟแสดงทัศนวิสัย (Visualization)
# ## Ex 11.2: Bar Chart (เปรียบเทียบ)

# %%
import matplotlib.pyplot as plt
plt.bar(['Zone A', 'Zone B'], [150, 90])
plt.title("Yield by Zone")
# plt.show()
