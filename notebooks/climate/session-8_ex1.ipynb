# %% [markdown]
# # API Cloud Connections
# ## Ex 8.1: จำลองดึงข้อมูล (Mock Fetch)

# %%
# สมมติเราดึงข้อมูล JSON จาก Cloud
live_data = {"rain_today": 12.5, "forecast": "Heavy Rain"}
print("พยากรณ์:", live_data["forecast"])
