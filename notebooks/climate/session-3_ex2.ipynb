# %% [markdown]
# # สถาปัตยกรรมการตัดสินใจ (If-Else Logic)
# ## Ex 3.2: If-Else การวิเคราะห์ความชื้น

# %%
moisture = 40.5
if moisture < 45:
    print("เปิดระบบน้ำ")
else:
    print("ความชื้นเพียงพอ")
