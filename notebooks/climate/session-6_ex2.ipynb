# %% [markdown]
# # สร้างคำสั่งควบคุม (Functions)
# ## Ex 6.2: Def พร้อมพารามิเตอร์

# %%
def spray(zone_name, minutes):
    print(f"เปิดพ่นหมอก {zone_name} เป็นเวลา {minutes} นาที")

spray("โซนป่าดิบ", 10)
