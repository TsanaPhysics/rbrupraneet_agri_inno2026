# %% [markdown]
# # สถาปัตยกรรมการตัดสินใจ (If-Else Logic)
# ## Ex 3.3: Complex Logic (And/Or)

# %%
temp = 34.0
humidity = 85
if temp > 32 and humidity > 80:
    print("⚠️ เตือนภัยเชื้อรา และ แมลงปากดูด!")
