# %% [markdown]
# # สร้างคำสั่งควบคุม (Functions)
# ## Ex 6.3: Def พร้อมค่า Return

# %%
def calc_heat_index(t, h):
    return t + (0.05 * h)

idx = calc_heat_index(33.0, 75)
print(f"ดัชนีคำนวณได้: {idx:.1f}")
