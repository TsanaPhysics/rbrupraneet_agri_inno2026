# %% [markdown]
# # สร้างกราฟแสดงทัศนวิสัย (Visualization)
# ## Ex 11.3: Dark Mode Customization

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
plt.plot([2020, 2021], [1500, 1100], color='#f97316')
# plt.show()
